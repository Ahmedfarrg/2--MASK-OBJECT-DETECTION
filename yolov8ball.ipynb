# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="einay3T5Sr7xOcpMaQh8")
project = rf.workspace("nikhil-chapre-xgndf").project("detect-players-dgxz0")
version = project.version(7)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Detect-Players--7 in yolov8:: 100%|██████████| 2936/2936 [00:01<00:00, 2717.15it/s]

# %%
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics

# %%
from ultralytics import YOLO
# !yolo task=detect mode=train model=yolov8m.pt data=/content/datasets/Detect-Players--7/data.yaml epochs=30 imgsz=640 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.2.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/datasets/runs/detect/train3/weights/best.pt conf=0.35 source=/content/vid.mp4 save=True
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25841497 parameters, 0 gradients, 78.7 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# video 1/1 (1/686) /content/vid.mp4: 640x384 1 Ball, 8 Players, 118.2ms
# video 1/1 (2/686) /content/vid.mp4: 640x384 1 Ball, 11 Players, 25.1ms
# video 1/1 (3/686) /content/vid.mp4: 640x384 1 Ball, 8 Players, 25.0ms
# video 1/1 (4/686) /content/vid.mp4: 640x384 1 Ball, 9 Players, 25.0ms
# video 1/1 (5/686) /content/vid.mp4: 640x384 1 Ball, 8 Players, 25.1ms
# video 1/1 (6/686) /content/vid.mp4: 640x384 1 Ball, 10 Players, 22.4ms
# video 1/1 (7/686) /content/vid.mp4: 640x384 1 Ball, 10 Players, 18.3ms
# video 1/1 (8/686) /content/vid.mp4: 640x384 1 Ball, 10 Players, 18.3ms
# video 1/1 (9/686) /content/vid.mp4: 640x384 1 Ball, 8 Players, 18.3ms
# video 1/1 (10/686) /content/vid.mp4: 640x384 1 Ball, 10 Players, 18.3ms
# ...
